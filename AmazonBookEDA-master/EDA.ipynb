# %%
import pandas as pd
import numpy as np

# %%
amazon = pd.read_csv("amazon.csv")

# %%
amazon
# Out:
#                                                   Name              Author  \
# 0                        10-Day Green Smoothie Cleanse            JJ Smith
# 1                                    11/22/63: A Novel        Stephen King
# 2              12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson
# 3                                                 1984       George Orwell
# 4                               1984 (Signet Classics)       George Orwell
# ..                                                 ...                 ...
# 645       Wrecking Ball (Diary of a Wimpy Kid Book 14)         Jeff Kinney
# 646  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 647  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 648  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 649  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
#
#      User Rating  Reviews   Price  Price_r  Year        Genre
# 0            4.7    17350   $8.00        8  2016  Non Fiction
# 1            4.6     2052  $22.00       22  2011      Fiction
# 2            4.7    18979  $15.00       15  2018  Non Fiction
# 3            4.7    70425   $7.48        8  2021      Fiction
# 4            4.7    21424   $6.00        6  2017      Fiction
# ..           ...      ...     ...      ...   ...          ...
# 645          4.9     9413   $8.00        8  2019      Fiction
# 646          4.7    14331   $8.00        8  2016  Non Fiction
# 647          4.7    14331   $8.00        8  2017  Non Fiction
# 648          4.7    14331   $8.00        8  2018  Non Fiction
# 649          4.7    14331   $8.00        8  2019  Non Fiction
#
# [650 rows x 8 columns]

# %% [markdown]
# ## Preguntas

# %% [markdown]
# Por año cuantos libros ha publicado un autor, recuerde que los años no trabajados deberia de aparecer en cero. considere como primer registro por autor el primer año en que publico y el ultimo el año maximo encontrado.
#
# Ejemplo, si Uayeb public en 2009 dos libros, y en 2011 tres. y esas son las dos unicas entradas para este autor. la salida para el deberia de ser:

# %%
pd.DataFrame({ "Autor" : ["Uayeb","Uayeb","Uayeb"] , "Year" : [2009,2010,2011]  , "Conteo" : [2,0,3] })
# Out:
#    Autor  Year  Conteo
# 0  Uayeb  2009       2
# 1  Uayeb  2010       0
# 2  Uayeb  2011       3

# %%
datos_filtrados = amazon[["Name","Author", "Year", "Conteo"]]


agrupadosXanio = datos_filtrados.groupby('Author', axis=1)


agrupadosXanio.count()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [237], in <cell line: 7>()
#       1 datos_filtrados = amazon[["Name","Author", "Year", "Conteo"]]
#       4 agrupadosXanio = datos_filtrados.groupby('Author', axis=1)
# ----> 7 agrupadosXanio.count()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1863, in GroupBy.count(self)
#    1860         return counted[0]
#    1861     return counted
# -> 1863 new_mgr = data.grouped_reduce(hfunc)
#    1865 # If we are grouping on categoricals we want unobserved categories to
#    1866 # return zero, rather than the default of NaN which the reindexing in
#    1867 # _wrap_agged_manager() returns. GH 35028
#    1868 with com.temp_setattr(self, "observed", True):
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py:1338, in BlockManager.grouped_reduce(self, func, ignore_failures)
#    1336 for sb in blk._split():
#    1337     try:
# -> 1338         applied = sb.apply(func)
#    1339     except (TypeError, NotImplementedError):
#    1340         if not ignore_failures:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402, in Block.apply(self, func, **kwargs)
#     396 @final
#     397 def apply(self, func, **kwargs) -> list[Block]:
#     398     """
#     399     apply the function to my values; return a block if we are not
#     400     one
#     401     """
# --> 402     result = func(self.values, **kwargs)
#     404     return self._split_op_result(result)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1854, in GroupBy.count.<locals>.hfunc(bvalues)
#    1852     masked = mask & ~isna(bvalues).reshape(1, -1)
#    1853 else:
# -> 1854     masked = mask & ~isna(bvalues)
#    1856 counted = lib.count_level_2d(masked, labels=ids, max_bin=ngroups, axis=1)
#    1857 if is_series:
#
# ValueError: operands could not be broadcast together with shapes (4,) (1,3)

# %%
def conteo(Year):
    resultado =  ["Year"]
    resultado

# %%
amazon["Conteo"]=amazon.apply(conteo, axis=1)
amazon
# Out:
#                                                   Name              Author  \
# 0                        10-Day Green Smoothie Cleanse            JJ Smith
# 1                                    11/22/63: A Novel        Stephen King
# 2              12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson
# 3                                                 1984       George Orwell
# 4                               1984 (Signet Classics)       George Orwell
# ..                                                 ...                 ...
# 645       Wrecking Ball (Diary of a Wimpy Kid Book 14)         Jeff Kinney
# 646  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 647  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 648  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 649  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
#
#      User Rating  Reviews   Price  Price_r  Year        Genre Conteo
# 0            4.7    17350   $8.00        8  2016  Non Fiction   None
# 1            4.6     2052  $22.00       22  2011      Fiction   None
# 2            4.7    18979  $15.00       15  2018  Non Fiction   None
# 3            4.7    70425   $7.48        8  2021      Fiction   None
# 4            4.7    21424   $6.00        6  2017      Fiction   None
# ..           ...      ...     ...      ...   ...          ...    ...
# 645          4.9     9413   $8.00        8  2019      Fiction   None
# 646          4.7    14331   $8.00        8  2016  Non Fiction   None
# 647          4.7    14331   $8.00        8  2017  Non Fiction   None
# 648          4.7    14331   $8.00        8  2018  Non Fiction   None
# 649          4.7    14331   $8.00        8  2019  Non Fiction   None
#
# [650 rows x 9 columns]

# %%
autorXlibro = datos_filtrados.loc[ : , ["Author","Name"] ].drop_duplicates()
autorXanio = datos_filtrados.loc[ : , ["Author","Year"] ].drop_duplicates()

# %%
conteo_autorXlibro = autorXlibro.groupby(["Author"],as_index=False).agg({ 'Name' : ['count'] })
conteo_autorXanio = autorXanio.groupby(["Year"],as_index=False).agg({ 'Author' : ['count'] })

# %%
df3 = datos_filtrados.max()

# %%
conteo_autorXlibro.columns = conteo_autorXlibro.columns.droplevel(1)
conteo_autorXanio.columns = conteo_autorXanio.columns.droplevel(1)

# %%
conteo_autorXlibro.merge( conteo_autorXanio , on=['Author'] , how='inner' )
# Out:
#                  Author  Name  Year
# 0      Abraham Verghese     1     2
# 1        Adam Gasiewski     1     1
# 2         Adam Mansbach     1     1
# 3          Adam Silvera     1     1
# 4          Adam Wallace     2     2
# ..                  ...   ...   ...
# 287    William P. Young     1     2
# 288    Wizards RPG Team     1     3
# 289  Wonder House Books     1     1
# 290  Workman Publishing     2     2
# 291        Zhi Gang Sha     2     2
#
# [292 rows x 3 columns]

# %%
autores = datos_filtrados.groupby(amazon['Author'])

autores.max()
# Out:
#                                                                  Name  \
# Author
# Abraham Verghese                                    Cutting for Stone
# Adam Gasiewski      Milk and Vine: Inspirational Quotes From Class...
# Adam Mansbach                                    Go the F**k to Sleep
# Adam Silvera                                 They Both Die at the End
# Adam Wallace                                   How to Catch a Unicorn
# ...                                                               ...
# William P. Young          The Shack: Where Tragedy Confronts Eternity
# Wizards RPG Team               Player's Handbook (Dungeons & Dragons)
# Wonder House Books  My First LIbrary: Boxset of 10 Board Books for...
# Workman Publishing  Paint by Sticker Kids: Zoo Animals: Create 10 ...
# Zhi Gang Sha        Soul Healing Miracles: Ancient and New Sacred ...
#
#                                 Author  Year
# Author
# Abraham Verghese      Abraham Verghese  2011
# Adam Gasiewski          Adam Gasiewski  2017
# Adam Mansbach            Adam Mansbach  2011
# Adam Silvera              Adam Silvera  2021
# Adam Wallace              Adam Wallace  2021
# ...                                ...   ...
# William P. Young      William P. Young  2017
# Wizards RPG Team      Wizards RPG Team  2019
# Wonder House Books  Wonder House Books  2021
# Workman Publishing  Workman Publishing  2021
# Zhi Gang Sha              Zhi Gang Sha  2013
#
# [292 rows x 3 columns]

# %% [markdown]
# Que Autores han trabado en un año en mas de un libro
#
# Ejemplo de salida esperada:

# %%
pd.DataFrame({
    
    "Autor" : ['Uayeb','Imix']
    , "Year" : [2010, 2010]
    , "Conteo de Titulos" : [2 , 3]
    
})
# Out:
#    Autor  Year  Conteo de Titulos
# 0  Uayeb  2010                  2
# 1   Imix  2010                  3

# %% [markdown]
# Que genero por año ha obtenido el mejor rating en promedio. (solo deberia de obtener un registro por año)
#
# - ejemplo de la salida esperada:

# %%
pd.DataFrame({
    "Year" : [2009,2010]
    , "Genre" : [ "Fiction" , "Fiction" ]
    , "Mean User Rating": [ 4.59 , 4.61 ]
})
# Out:
#    Year    Genre  Mean User Rating
# 0  2009  Fiction              4.59
# 1  2010  Fiction              4.61

# %% [markdown]
# Cuales son los autores que por lo menos dos años consecutivos hayan tenido en promedio ratings que decrecen
#
# Ejemplo
#
# - Si Uayeb caballero, en 2010 saco dos libros, y el rating de esos dos libros es de 3.1, ese mismo autor en 2011 en su unico libro publicado ese año su promedio fue de 2.9 y en 2012 sus tres libros publicados en promedio su rating es de 2.8. Podemos ver que son dos años que este usuario ha ido decreciendo
#
# No importa que haya publicado en años salteados, ejemplo, 2010 si, 2011 no, 2012 no, 2013 si, 2014 si. para este caso el analisis comienza en 2010, 2013 y 2014
#
# Ejemplo de salida esperada:

# %%
pd.DataFrame({ "autores" : ['Uayeb','Imix'] })
# Out:
#   autores
# 0   Uayeb
# 1    Imix

# %% [markdown]
# Cuales son los libros que por año se encuentran arriba del percentil 70. (Sin importar genero)
#
# Ejemplo de salida esperada

# %%
pd.DataFrame({
    "Year": [2010,2010,2011,2011]
    , "Titulos": ["Libro A","Libro B","Libro Z","Libro Y"]
    , "Autor": ["Autor 1","Autor 2","Autor 1","Autor 3"]
    , "Rating": [4.1, 4.0,4.2,4.3]
    , "Rating .70": [3.8,3.8,3.7,3.7]
})
# Out:
#    Year  Titulos    Autor  Rating  Rating .70
# 0  2010  Libro A  Autor 1     4.1         3.8
# 1  2010  Libro B  Autor 2     4.0         3.8
# 2  2011  Libro Z  Autor 1     4.2         3.7
# 3  2011  Libro Y  Autor 3     4.3         3.7

# %% [markdown]
# Este ejemplo es para que se haga una idea de la estructura de salida esperada, claramente por año dependiendo de las publicaciones pueden haber varios libros arriba del percentil 70
